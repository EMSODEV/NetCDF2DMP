# %%
from netcdf2dmp import EMSO2DMP

# %%
ncfolder='C:\\Users\\Robert\\workspace\\fixo3_nc2md\\cache\\'
file='EuroSITES_10_OS_ANTARES_2010_R_CTD.nc'
#file='EuroSITES_19_OS_PAP-1_201009_R_PCO2.nc'
ds= EMSO2DMP()
ds.open(ncfolder+file)
# Out:
# No error

# %%
print(ds.dataTypeNames[ds.type])
# Out:
# Time series profile

# %%
for sensor in ds.sensors.values():
    print(sensor.id)
    #xmlstr=ds.createInsertSensorXML(sensor)
    xmlstr=ds.createInsertResultTemplateXML(sensor)
    print(xmlstr)
# Out:
# fbb2c87f-8d9d-356f-b7c0-e4e1acc82492
# <sos:InsertResultTemplate service="SOS" version="2.0.0" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:swes="http://www.opengis.net/swes/2.0" xmlns:sos="http://www.opengis.net/sos/2.0" xmlns:swe="http://www.opengis.net/swe/2.0" xmlns:sml="http://www.opengis.net/sensorML/1.0.1" xmlns:gml="http://www.opengis.net/gml/3.2" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:om="http://www.opengis.net/om/2.0" xmlns:sams="http://www.opengis.net/samplingSpatial/2.0" xmlns:sf="http://www.opengis.net/sampling/2.0" xmlns:xs="http://www.w3.org/2001/XMLSchema" xsi:schemaLocation="http://www.opengis.net/sos/2.0 http://schemas.opengis.net/sos/2.0/sosInsertResultTemplate.xsd http://www.opengis.net/om/2.0 http://schemas.opengis.net/om/2.0/observation.xsd  http://www.opengis.net/samplingSpatial/2.0 http://schemas.opengis.net/samplingSpatial/2.0/spatialSamplingFeature.xsd"><sos:proposedTemplate><sos:ResultTemplate><swes:identifier>s_fbb2c87f-8d9d-356f-b7c0-e4e1acc82492_ANTARES_2008-01-25</swes:identifier><swes:extension><sml:attachedTo xlink:href="http://emso.eu/platform/ANTARES" xlink:title="emso.eu:deployment:ANTARES:ANTARES:2008-01-25"/></swes:extension><sos:offering>offering_s_fbb2c87f-8d9d-356f-b7c0-e4e1acc82492</sos:offering><sos:observationTemplate><om:OM_Observation gml:id="sensor2obsTemplate"><om:type xlink:href="http://www.opengis.net/def/observationType/OGC-OM/2.0/OM_ComplexObservation"/><om:phenomenonTime nilReason="template"/><om:resultTime nilReason="template"/><om:procedure xlink:href="s_fbb2c87f-8d9d-356f-b7c0-e4e1acc82492"/><om:observedProperty xlink:href="s_fbb2c87f-8d9d-356f-b7c0-e4e1acc82492_observations"/><om:featureOfInterest><sams:SF_SpatialSamplingFeature gml:id="ANTARES"><gml:identifier codeSpace="EMSO">http://www.emso.eu/site/ANTARES</gml:identifier><gml:name>ANTARES</gml:name><sf:type xlink:href="http://www.opengis.net/def/samplingFeatureType/OGC-OM/2.0/SF_SamplingPoint"/><sf:sampledFeature xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown"/><sams:shape><gml:Point gml:id="ANTARES_coordinates"><gml:pos srsName="http://www.opengis.net/def/crs/EPSG/0/4326">42.8 6.17</gml:pos></gml:Point></sams:shape></sams:SF_SpatialSamplingFeature></om:featureOfInterest><om:result/></om:OM_Observation></sos:observationTemplate><sos:resultStructure><swe:DataRecord><swe:field name="phenomenonTime"><swe:Time definition="http://www.opengis.net/def/property/OGC/0/PhenomenonTime"><swe:uom xlink:href="http://www.opengis.net/def/uom/ISO-8601/0/Gregorian"/></swe:Time></swe:field><swe:field name="s_fbb2c87f-8d9d-356f-b7c0-e4e1acc82492_data_container"><swe:DataRecord definition="s_fbb2c87f-8d9d-356f-b7c0-e4e1acc82492_observations"><swe:field name="sea_water_temperature"><swe:Quantity definition="http://mmisw.org/ont/cf/parameter/sea_water_temperature"><swe:identifier>TEMP</swe:identifier><swe:label>sea water temperature</swe:label><swe:description>sea_water_temperature (TEMP)</swe:description><swe:uom code="degree_Celsius"/></swe:Quantity></swe:field><swe:field name="sea_water_electrical_conductivity"><swe:Quantity definition="http://mmisw.org/ont/cf/parameter/sea_water_electrical_conductivity"><swe:identifier>CNDC</swe:identifier><swe:label>sea water electrical conductivity</swe:label><swe:description>sea_water_electrical_conductivity (CNDC)</swe:description><swe:uom code="S/m"/></swe:Quantity></swe:field><swe:field name="sea_water_practical_salinity"><swe:Quantity definition="http://mmisw.org/ont/cf/parameter/sea_water_practical_salinity"><swe:identifier>PSAL</swe:identifier><swe:label>sea water practical salinity</swe:label><swe:description>sea_water_practical_salinity (PSAL)</swe:description><swe:uom code="psu"/></swe:Quantity></swe:field><swe:field name="mole_concentration_of_dissolved_molecular_oxygen_in_sea_water_at_saturation"><swe:Quantity definition="http://mmisw.org/ont/cf/parameter/mole_concentration_of_dissolved_molecular_oxygen_in_sea_water_at_saturation"><swe:identifier>OSAT</swe:identifier><swe:label>mole concentra ...
# be0f6ec4-f0d0-3099-a61f-0d83695e54e0
# <sos:InsertResultTemplate service="SOS" version="2.0.0" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:swes="http://www.opengis.net/swes/2.0" xmlns:sos="http://www.opengis.net/sos/2.0" xmlns:swe="http://www.opengis.net/swe/2.0" xmlns:sml="http://www.opengis.net/sensorML/1.0.1" xmlns:gml="http://www.opengis.net/gml/3.2" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:om="http://www.opengis.net/om/2.0" xmlns:sams="http://www.opengis.net/samplingSpatial/2.0" xmlns:sf="http://www.opengis.net/sampling/2.0" xmlns:xs="http://www.w3.org/2001/XMLSchema" xsi:schemaLocation="http://www.opengis.net/sos/2.0 http://schemas.opengis.net/sos/2.0/sosInsertResultTemplate.xsd http://www.opengis.net/om/2.0 http://schemas.opengis.net/om/2.0/observation.xsd  http://www.opengis.net/samplingSpatial/2.0 http://schemas.opengis.net/samplingSpatial/2.0/spatialSamplingFeature.xsd"><sos:proposedTemplate><sos:ResultTemplate><swes:identifier>s_be0f6ec4-f0d0-3099-a61f-0d83695e54e0_ANTARES_2008-01-25</swes:identifier><swes:extension><sml:attachedTo xlink:href="http://emso.eu/platform/ANTARES" xlink:title="emso.eu:deployment:ANTARES:ANTARES:2008-01-25"/></swes:extension><sos:offering>offering_s_be0f6ec4-f0d0-3099-a61f-0d83695e54e0</sos:offering><sos:observationTemplate><om:OM_Observation gml:id="sensor2obsTemplate"><om:type xlink:href="http://www.opengis.net/def/observationType/OGC-OM/2.0/OM_ComplexObservation"/><om:phenomenonTime nilReason="template"/><om:resultTime nilReason="template"/><om:procedure xlink:href="s_be0f6ec4-f0d0-3099-a61f-0d83695e54e0"/><om:observedProperty xlink:href="s_be0f6ec4-f0d0-3099-a61f-0d83695e54e0_observations"/><om:featureOfInterest><sams:SF_SpatialSamplingFeature gml:id="ANTARES"><gml:identifier codeSpace="EMSO">http://www.emso.eu/site/ANTARES</gml:identifier><gml:name>ANTARES</gml:name><sf:type xlink:href="http://www.opengis.net/def/samplingFeatureType/OGC-OM/2.0/SF_SamplingPoint"/><sf:sampledFeature xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown"/><sams:shape><gml:Point gml:id="ANTARES_coordinates"><gml:pos srsName="http://www.opengis.net/def/crs/EPSG/0/4326">42.8 6.17</gml:pos></gml:Point></sams:shape></sams:SF_SpatialSamplingFeature></om:featureOfInterest><om:result/></om:OM_Observation></sos:observationTemplate><sos:resultStructure><swe:DataRecord><swe:field name="phenomenonTime"><swe:Time definition="http://www.opengis.net/def/property/OGC/0/PhenomenonTime"><swe:uom xlink:href="http://www.opengis.net/def/uom/ISO-8601/0/Gregorian"/></swe:Time></swe:field><swe:field name="s_be0f6ec4-f0d0-3099-a61f-0d83695e54e0_data_container"><swe:DataRecord definition="s_be0f6ec4-f0d0-3099-a61f-0d83695e54e0_observations"><swe:field name="sea_water_temperature"><swe:Quantity definition="http://mmisw.org/ont/cf/parameter/sea_water_temperature"><swe:identifier>TEMP</swe:identifier><swe:label>sea water temperature</swe:label><swe:description>sea_water_temperature (TEMP)</swe:description><swe:uom code="degree_Celsius"/></swe:Quantity></swe:field><swe:field name="sea_water_electrical_conductivity"><swe:Quantity definition="http://mmisw.org/ont/cf/parameter/sea_water_electrical_conductivity"><swe:identifier>CNDC</swe:identifier><swe:label>sea water electrical conductivity</swe:label><swe:description>sea_water_electrical_conductivity (CNDC)</swe:description><swe:uom code="S/m"/></swe:Quantity></swe:field><swe:field name="sea_water_practical_salinity"><swe:Quantity definition="http://mmisw.org/ont/cf/parameter/sea_water_practical_salinity"><swe:identifier>PSAL</swe:identifier><swe:label>sea water practical salinity</swe:label><swe:description>sea_water_practical_salinity (PSAL)</swe:description><swe:uom code="psu"/></swe:Quantity></swe:field><swe:field name="mole_concentration_of_dissolved_molecular_oxygen_in_sea_water_at_saturation"><swe:Quantity definition="http://mmisw.org/ont/cf/parameter/mole_concentration_of_dissolved_molecular_oxygen_in_sea_water_at_saturation"><swe:identifier>OSAT</swe:identifier><swe:label>mole concentra ...
# 1bfc18ac-0b97-330a-be1b-0c47bf47f1a3
# <sos:InsertResultTemplate service="SOS" version="2.0.0" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:swes="http://www.opengis.net/swes/2.0" xmlns:sos="http://www.opengis.net/sos/2.0" xmlns:swe="http://www.opengis.net/swe/2.0" xmlns:sml="http://www.opengis.net/sensorML/1.0.1" xmlns:gml="http://www.opengis.net/gml/3.2" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:om="http://www.opengis.net/om/2.0" xmlns:sams="http://www.opengis.net/samplingSpatial/2.0" xmlns:sf="http://www.opengis.net/sampling/2.0" xmlns:xs="http://www.w3.org/2001/XMLSchema" xsi:schemaLocation="http://www.opengis.net/sos/2.0 http://schemas.opengis.net/sos/2.0/sosInsertResultTemplate.xsd http://www.opengis.net/om/2.0 http://schemas.opengis.net/om/2.0/observation.xsd  http://www.opengis.net/samplingSpatial/2.0 http://schemas.opengis.net/samplingSpatial/2.0/spatialSamplingFeature.xsd"><sos:proposedTemplate><sos:ResultTemplate><swes:identifier>s_1bfc18ac-0b97-330a-be1b-0c47bf47f1a3_ANTARES_2008-01-25</swes:identifier><swes:extension><sml:attachedTo xlink:href="http://emso.eu/platform/ANTARES" xlink:title="emso.eu:deployment:ANTARES:ANTARES:2008-01-25"/></swes:extension><sos:offering>offering_s_1bfc18ac-0b97-330a-be1b-0c47bf47f1a3</sos:offering><sos:observationTemplate><om:OM_Observation gml:id="sensor2obsTemplate"><om:type xlink:href="http://www.opengis.net/def/observationType/OGC-OM/2.0/OM_ComplexObservation"/><om:phenomenonTime nilReason="template"/><om:resultTime nilReason="template"/><om:procedure xlink:href="s_1bfc18ac-0b97-330a-be1b-0c47bf47f1a3"/><om:observedProperty xlink:href="s_1bfc18ac-0b97-330a-be1b-0c47bf47f1a3_observations"/><om:featureOfInterest><sams:SF_SpatialSamplingFeature gml:id="ANTARES"><gml:identifier codeSpace="EMSO">http://www.emso.eu/site/ANTARES</gml:identifier><gml:name>ANTARES</gml:name><sf:type xlink:href="http://www.opengis.net/def/samplingFeatureType/OGC-OM/2.0/SF_SamplingPoint"/><sf:sampledFeature xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown"/><sams:shape><gml:Point gml:id="ANTARES_coordinates"><gml:pos srsName="http://www.opengis.net/def/crs/EPSG/0/4326">42.8 6.17</gml:pos></gml:Point></sams:shape></sams:SF_SpatialSamplingFeature></om:featureOfInterest><om:result/></om:OM_Observation></sos:observationTemplate><sos:resultStructure><swe:DataRecord><swe:field name="phenomenonTime"><swe:Time definition="http://www.opengis.net/def/property/OGC/0/PhenomenonTime"><swe:uom xlink:href="http://www.opengis.net/def/uom/ISO-8601/0/Gregorian"/></swe:Time></swe:field><swe:field name="s_1bfc18ac-0b97-330a-be1b-0c47bf47f1a3_data_container"><swe:DataRecord definition="s_1bfc18ac-0b97-330a-be1b-0c47bf47f1a3_observations"><swe:field name="sea_water_temperature"><swe:Quantity definition="http://mmisw.org/ont/cf/parameter/sea_water_temperature"><swe:identifier>TEMP</swe:identifier><swe:label>sea water temperature</swe:label><swe:description>sea_water_temperature (TEMP)</swe:description><swe:uom code="degree_Celsius"/></swe:Quantity></swe:field><swe:field name="sea_water_electrical_conductivity"><swe:Quantity definition="http://mmisw.org/ont/cf/parameter/sea_water_electrical_conductivity"><swe:identifier>CNDC</swe:identifier><swe:label>sea water electrical conductivity</swe:label><swe:description>sea_water_electrical_conductivity (CNDC)</swe:description><swe:uom code="S/m"/></swe:Quantity></swe:field><swe:field name="sea_water_practical_salinity"><swe:Quantity definition="http://mmisw.org/ont/cf/parameter/sea_water_practical_salinity"><swe:identifier>PSAL</swe:identifier><swe:label>sea water practical salinity</swe:label><swe:description>sea_water_practical_salinity (PSAL)</swe:description><swe:uom code="psu"/></swe:Quantity></swe:field><swe:field name="mole_concentration_of_dissolved_molecular_oxygen_in_sea_water_at_saturation"><swe:Quantity definition="http://mmisw.org/ont/cf/parameter/mole_concentration_of_dissolved_molecular_oxygen_in_sea_water_at_saturation"><swe:identifier>OSAT</swe:identifier><swe:label>mole concentra ...
# 0a8eccfd-1bc1-39af-8537-5e8b0c4eeaa7
# <sos:InsertResultTemplate service="SOS" version="2.0.0" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:swes="http://www.opengis.net/swes/2.0" xmlns:sos="http://www.opengis.net/sos/2.0" xmlns:swe="http://www.opengis.net/swe/2.0" xmlns:sml="http://www.opengis.net/sensorML/1.0.1" xmlns:gml="http://www.opengis.net/gml/3.2" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:om="http://www.opengis.net/om/2.0" xmlns:sams="http://www.opengis.net/samplingSpatial/2.0" xmlns:sf="http://www.opengis.net/sampling/2.0" xmlns:xs="http://www.w3.org/2001/XMLSchema" xsi:schemaLocation="http://www.opengis.net/sos/2.0 http://schemas.opengis.net/sos/2.0/sosInsertResultTemplate.xsd http://www.opengis.net/om/2.0 http://schemas.opengis.net/om/2.0/observation.xsd  http://www.opengis.net/samplingSpatial/2.0 http://schemas.opengis.net/samplingSpatial/2.0/spatialSamplingFeature.xsd"><sos:proposedTemplate><sos:ResultTemplate><swes:identifier>s_0a8eccfd-1bc1-39af-8537-5e8b0c4eeaa7_ANTARES_2008-01-25</swes:identifier><swes:extension><sml:attachedTo xlink:href="http://emso.eu/platform/ANTARES" xlink:title="emso.eu:deployment:ANTARES:ANTARES:2008-01-25"/></swes:extension><sos:offering>offering_s_0a8eccfd-1bc1-39af-8537-5e8b0c4eeaa7</sos:offering><sos:observationTemplate><om:OM_Observation gml:id="sensor2obsTemplate"><om:type xlink:href="http://www.opengis.net/def/observationType/OGC-OM/2.0/OM_ComplexObservation"/><om:phenomenonTime nilReason="template"/><om:resultTime nilReason="template"/><om:procedure xlink:href="s_0a8eccfd-1bc1-39af-8537-5e8b0c4eeaa7"/><om:observedProperty xlink:href="s_0a8eccfd-1bc1-39af-8537-5e8b0c4eeaa7_observations"/><om:featureOfInterest><sams:SF_SpatialSamplingFeature gml:id="ANTARES"><gml:identifier codeSpace="EMSO">http://www.emso.eu/site/ANTARES</gml:identifier><gml:name>ANTARES</gml:name><sf:type xlink:href="http://www.opengis.net/def/samplingFeatureType/OGC-OM/2.0/SF_SamplingPoint"/><sf:sampledFeature xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown"/><sams:shape><gml:Point gml:id="ANTARES_coordinates"><gml:pos srsName="http://www.opengis.net/def/crs/EPSG/0/4326">42.8 6.17</gml:pos></gml:Point></sams:shape></sams:SF_SpatialSamplingFeature></om:featureOfInterest><om:result/></om:OM_Observation></sos:observationTemplate><sos:resultStructure><swe:DataRecord><swe:field name="phenomenonTime"><swe:Time definition="http://www.opengis.net/def/property/OGC/0/PhenomenonTime"><swe:uom xlink:href="http://www.opengis.net/def/uom/ISO-8601/0/Gregorian"/></swe:Time></swe:field><swe:field name="s_0a8eccfd-1bc1-39af-8537-5e8b0c4eeaa7_data_container"><swe:DataRecord definition="s_0a8eccfd-1bc1-39af-8537-5e8b0c4eeaa7_observations"><swe:field name="sea_water_temperature"><swe:Quantity definition="http://mmisw.org/ont/cf/parameter/sea_water_temperature"><swe:identifier>TEMP</swe:identifier><swe:label>sea water temperature</swe:label><swe:description>sea_water_temperature (TEMP)</swe:description><swe:uom code="degree_Celsius"/></swe:Quantity></swe:field><swe:field name="sea_water_electrical_conductivity"><swe:Quantity definition="http://mmisw.org/ont/cf/parameter/sea_water_electrical_conductivity"><swe:identifier>CNDC</swe:identifier><swe:label>sea water electrical conductivity</swe:label><swe:description>sea_water_electrical_conductivity (CNDC)</swe:description><swe:uom code="S/m"/></swe:Quantity></swe:field><swe:field name="sea_water_practical_salinity"><swe:Quantity definition="http://mmisw.org/ont/cf/parameter/sea_water_practical_salinity"><swe:identifier>PSAL</swe:identifier><swe:label>sea water practical salinity</swe:label><swe:description>sea_water_practical_salinity (PSAL)</swe:description><swe:uom code="psu"/></swe:Quantity></swe:field><swe:field name="mole_concentration_of_dissolved_molecular_oxygen_in_sea_water_at_saturation"><swe:Quantity definition="http://mmisw.org/ont/cf/parameter/mole_concentration_of_dissolved_molecular_oxygen_in_sea_water_at_saturation"><swe:identifier>OSAT</swe:identifier><swe:label>mole concentra ...
# 70870219-57bf-3436-af59-8839716ac6bb
# <sos:InsertResultTemplate service="SOS" version="2.0.0" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:swes="http://www.opengis.net/swes/2.0" xmlns:sos="http://www.opengis.net/sos/2.0" xmlns:swe="http://www.opengis.net/swe/2.0" xmlns:sml="http://www.opengis.net/sensorML/1.0.1" xmlns:gml="http://www.opengis.net/gml/3.2" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:om="http://www.opengis.net/om/2.0" xmlns:sams="http://www.opengis.net/samplingSpatial/2.0" xmlns:sf="http://www.opengis.net/sampling/2.0" xmlns:xs="http://www.w3.org/2001/XMLSchema" xsi:schemaLocation="http://www.opengis.net/sos/2.0 http://schemas.opengis.net/sos/2.0/sosInsertResultTemplate.xsd http://www.opengis.net/om/2.0 http://schemas.opengis.net/om/2.0/observation.xsd  http://www.opengis.net/samplingSpatial/2.0 http://schemas.opengis.net/samplingSpatial/2.0/spatialSamplingFeature.xsd"><sos:proposedTemplate><sos:ResultTemplate><swes:identifier>s_70870219-57bf-3436-af59-8839716ac6bb_ANTARES_2008-01-25</swes:identifier><swes:extension><sml:attachedTo xlink:href="http://emso.eu/platform/ANTARES" xlink:title="emso.eu:deployment:ANTARES:ANTARES:2008-01-25"/></swes:extension><sos:offering>offering_s_70870219-57bf-3436-af59-8839716ac6bb</sos:offering><sos:observationTemplate><om:OM_Observation gml:id="sensor2obsTemplate"><om:type xlink:href="http://www.opengis.net/def/observationType/OGC-OM/2.0/OM_ComplexObservation"/><om:phenomenonTime nilReason="template"/><om:resultTime nilReason="template"/><om:procedure xlink:href="s_70870219-57bf-3436-af59-8839716ac6bb"/><om:observedProperty xlink:href="s_70870219-57bf-3436-af59-8839716ac6bb_observations"/><om:featureOfInterest><sams:SF_SpatialSamplingFeature gml:id="ANTARES"><gml:identifier codeSpace="EMSO">http://www.emso.eu/site/ANTARES</gml:identifier><gml:name>ANTARES</gml:name><sf:type xlink:href="http://www.opengis.net/def/samplingFeatureType/OGC-OM/2.0/SF_SamplingPoint"/><sf:sampledFeature xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown"/><sams:shape><gml:Point gml:id="ANTARES_coordinates"><gml:pos srsName="http://www.opengis.net/def/crs/EPSG/0/4326">42.8 6.17</gml:pos></gml:Point></sams:shape></sams:SF_SpatialSamplingFeature></om:featureOfInterest><om:result/></om:OM_Observation></sos:observationTemplate><sos:resultStructure><swe:DataRecord><swe:field name="phenomenonTime"><swe:Time definition="http://www.opengis.net/def/property/OGC/0/PhenomenonTime"><swe:uom xlink:href="http://www.opengis.net/def/uom/ISO-8601/0/Gregorian"/></swe:Time></swe:field><swe:field name="s_70870219-57bf-3436-af59-8839716ac6bb_data_container"><swe:DataRecord definition="s_70870219-57bf-3436-af59-8839716ac6bb_observations"><swe:field name="sea_water_temperature"><swe:Quantity definition="http://mmisw.org/ont/cf/parameter/sea_water_temperature"><swe:identifier>TEMP</swe:identifier><swe:label>sea water temperature</swe:label><swe:description>sea_water_temperature (TEMP)</swe:description><swe:uom code="degree_Celsius"/></swe:Quantity></swe:field><swe:field name="sea_water_electrical_conductivity"><swe:Quantity definition="http://mmisw.org/ont/cf/parameter/sea_water_electrical_conductivity"><swe:identifier>CNDC</swe:identifier><swe:label>sea water electrical conductivity</swe:label><swe:description>sea_water_electrical_conductivity (CNDC)</swe:description><swe:uom code="S/m"/></swe:Quantity></swe:field><swe:field name="sea_water_practical_salinity"><swe:Quantity definition="http://mmisw.org/ont/cf/parameter/sea_water_practical_salinity"><swe:identifier>PSAL</swe:identifier><swe:label>sea water practical salinity</swe:label><swe:description>sea_water_practical_salinity (PSAL)</swe:description><swe:uom code="psu"/></swe:Quantity></swe:field><swe:field name="mole_concentration_of_dissolved_molecular_oxygen_in_sea_water_at_saturation"><swe:Quantity definition="http://mmisw.org/ont/cf/parameter/mole_concentration_of_dissolved_molecular_oxygen_in_sea_water_at_saturation"><swe:identifier>OSAT</swe:identifier><swe:label>mole concentra ...

# %%
print(ds.deployment)
# Out:
# emso.eu:deployment:ANTARES@ANTARES:2008-01-25
